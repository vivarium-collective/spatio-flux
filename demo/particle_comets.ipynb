# %%
from process_bigraph import Composite
from spatio_flux import core
from spatio_flux.viz.plot import plot_time_series, plot_species_distributions_with_particles_to_gif
from spatio_flux.processes.dfba import DynamicFBA, get_single_dfba_spec, get_spatial_dfba_state
from spatio_flux.processes.diffusion_advection import DiffusionAdvection, get_diffusion_advection_spec
from spatio_flux.processes.particles import Particles, get_particles_spec, get_particles_state

# %% [markdown]
# # dFBA

# %%
total_time = 60
single_dfba_config = get_single_dfba_spec(path=['fields'])

# make the simulation
sim = Composite({
    'state': single_dfba_config,
    'emitter': {'mode': 'all'}
}, core=core)

sim.update({}, total_time)
dfba_results = sim.gather_results()

plot_time_series(
    dfba_results,
    # coordinates=[(0, 0), (1, 1), (2, 2)],
    out_dir='out',
    filename='dfba_timeseries.png',
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 13
#      10 sim.update({}, total_time)
#      11 dfba_results = sim.gather_results()
# ---> 13 plot_time_series(
#      14     dfba_results,
#      15     # coordinates=[(0, 0), (1, 1), (2, 2)],
#      16     out_dir='out',
#      17     filename='dfba_timeseries.png',
#      18 )
#
# File ~/code/spatio-flux/spatio_flux/viz/plot.py:50, in plot_time_series(results, field_names, coordinates, out_dir, filename, display)
#      48 coordinates = coordinates or [(0, 0)]
#      49 field_names = field_names or ['glucose', 'acetate', 'biomass']
# ---> 50 sorted_results = sort_results(results)
#      51 time = sorted_results['time']
#      53 # Initialize the plot
#
# File ~/code/spatio-flux/spatio_flux/viz/plot.py:18, in sort_results(results)
#      15 def sort_results(results):
#      16     emitter_results = results[('emitter',)]
#      17     sorted_results = {'fields': {
# ---> 18         key: [] for key in emitter_results[0]['fields'].keys()
#      19     }, 'time': []}
#      21     for results in emitter_results:
#      22         time = results['global_time']
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# # Spatial dFBA

# %%
total_time=30
n_bins=(5, 5)
mol_ids = ['glucose', 'acetate', 'biomass']

spatial_dfba_config = get_spatial_dfba_state(
    n_bins=n_bins,
    mol_ids=mol_ids,
)

# make the simulation
sim = Composite({
    'state': spatial_dfba_config,
    'emitter': {'mode': 'all'}
}, core=core)
sim.update({}, total_time)
dfba_results = sim.gather_results()

plot_time_series(
    dfba_results,
    coordinates=[(0, 0), (1, 1), (2, 2)],
    out_dir='out',
    filename='dfba_timeseries.png',
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 15
#      10 # make the simulation
#      11 sim = Composite({
#      12     'state': spatial_dfba_config,
#      13     'emitter': {'mode': 'all'}
#      14 }, core=core)
# ---> 15 sim.update({}, total_time)
#      16 dfba_results = sim.gather_results()
#      18 plot_time_series(
#      19     dfba_results,
#      20     coordinates=[(0, 0), (1, 1), (2, 2)],
#      21     out_dir='out',
#      22     filename='dfba_timeseries.png',
#      23 )
#
# File ~/code/spatio-flux/venv/lib/python3.11/site-packages/process_bigraph/composite.py:1216, in Composite.update(self, state, interval)
#    1207 projection = self.core.project(
#    1208     self.interface()['inputs'],
#    1209     self.bridge['inputs'],
#    1210     [],
#    1211     state)
#    1213 self.merge(
#    1214     projection)
# -> 1216 self.run(interval)
#    1218 updates = self.bridge_updates
#    1219 self.bridge_updates = []
#
# File ~/code/spatio-flux/venv/lib/python3.11/site-packages/process_bigraph/composite.py:1089, in Composite.run(self, interval, force_complete)
#    1087     update_paths = self.apply_updates(updates)
#    1088     self.expire_process_paths(update_paths)
# -> 1089     self.trigger_steps(update_paths)
#    1091     # # display and emit
#    1092     # if self.progress_bar:
#    1093     #     print_progress_bar(self.global_time, end_time)
#    (...)
#    1101 else:
#    1102     # all processes have run past the interval
#    1103     self.state['global_time'] = end_time
#
# File ~/code/spatio-flux/venv/lib/python3.11/site-packages/process_bigraph/composite.py:1181, in Composite.trigger_steps(self, update_paths)
#    1178 self.reset_step_state(steps_to_run)
#    1179 to_run = self.cycle_step_state()
# -> 1181 self.run_steps(to_run)
#
# File ~/code/spatio-flux/venv/lib/python3.11/site-packages/process_bigraph/composite.py:1142, in Composite.run_steps(self, step_paths)
#    1132     step = get_path(
#    1133         self.state,
#    1134         step_path)
#    1136     state = self.core.view_edge(
#    1137         self.composition,
#    1138         self.state,
#    1139         step_path,
#    1140         'inputs')
# -> 1142     step_update = self.process_update(
#    1143         step_path,
#    1144         step,
#    1145         state,
#    1146         -1.0,
#    1147         'outputs')
#    1149     updates.append(step_update)
#    1151 update_paths = self.apply_updates(updates)
#
# File ~/code/spatio-flux/venv/lib/python3.11/site-packages/process_bigraph/composite.py:892, in Composite.process_update(self, path, process, states, interval, ports_key)
#     870 """Start generating a process's update.
#     871
#     872 This function is similar to :py:meth:`_invoke_process` except in
#    (...)
#     887     ``store``.
#     888 """
#     890 states = strip_schema_keys(states)
# --> 892 update = process['instance'].invoke(states, interval)
#     894 def defer_project(update, args):
#     895     schema, state, path = args
#
# File ~/code/spatio-flux/venv/lib/python3.11/site-packages/process_bigraph/composite.py:270, in Step.invoke(self, state, _)
#     269 def invoke(self, state, _=None):
# --> 270     update = self.update(state)
#     271     sync = SyncUpdate(update)
#     272     return sync
#
# File ~/code/spatio-flux/venv/lib/python3.11/site-packages/process_bigraph/composite.py:1275, in RAMEmitter.update(self, state)
#    1274 def update(self, state) -> Dict:
# -> 1275     self.history.append(copy.deepcopy(state))
#    1276     return {}
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
#     [... skipping similar frames: _deepcopy_dict at line 231 (1 times), deepcopy at line 146 (1 times)]
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/copy.py:271, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     269 if state is not None:
#     270     if deep:
# --> 271         state = deepcopy(state, memo)
#     272     if hasattr(y, '__setstate__'):
#     273         y.__setstate__(state)
#
#     [... skipping similar frames: _deepcopy_dict at line 231 (1 times), deepcopy at line 146 (1 times)]
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/copy.py:271, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     269 if state is not None:
#     270     if deep:
# --> 271         state = deepcopy(state, memo)
#     272     if hasattr(y, '__setstate__'):
#     273         y.__setstate__(state)
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/copy.py:288, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     286 if deep:
#     287     for item in listiter:
# --> 288         item = deepcopy(item, memo)
#     289         y.append(item)
#     290 else:
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/copy.py:153, in deepcopy(x, memo, _nil)
#     151 copier = getattr(x, "__deepcopy__", None)
#     152 if copier is not None:
# --> 153     y = copier(memo)
#     154 else:
#     155     reductor = dispatch_table.get(cls)
#
# File ~/code/spatio-flux/venv/lib/python3.11/site-packages/cobra/core/reaction.py:273, in Reaction.__deepcopy__(self, memo)
#     260 def __deepcopy__(self, memo: dict) -> "Reaction":
#     261     """Copy the reaction with memo.
#     262
#     263     Parameters
#    (...)
#     271         A new reaction that is a deep copy of the original reaction with memo.
#     272     """
# --> 273     cop = deepcopy(super(Reaction, self), memo)
#     274     return cop
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/copy.py:273, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     271     state = deepcopy(state, memo)
#     272 if hasattr(y, '__setstate__'):
# --> 273     y.__setstate__(state)
#     274 else:
#     275     if isinstance(state, tuple) and len(state) == 2:
#
# File ~/code/spatio-flux/venv/lib/python3.11/site-packages/cobra/core/reaction.py:932, in Reaction.__setstate__(self, state)
#     930     state["_gpr"] = state["_gene_reaction_rule"]
#     931 if type(state["_gpr"]) is str:
# --> 932     state["_gpr"] = GPR.from_string(state["_gpr"])
#     934 self.__dict__.update(state)
#     935 for x in state["_metabolites"]:
#
# File ~/code/spatio-flux/venv/lib/python3.11/site-packages/cobra/core/gene.py:378, in GPR.from_string(cls, string_gpr)
#     373         warn(
#     374             "Malformed gene_reaction_rule '{}'".format(escaped_str),
#     375             SyntaxWarning,
#     376         )
#     377         return gpr
# --> 378 gpr = cls(tree)
#     379 gpr.update_genes()
#     380 return gpr
#
# File ~/code/spatio-flux/venv/lib/python3.11/site-packages/cobra/core/gene.py:306, in GPR.__init__(self, gpr_from, **kwargs)
#     304     cleaner.visit(gpr_from)
#     305     self._genes = deepcopy(cleaner.gene_set)
# --> 306     self.body = deepcopy(gpr_from.body)
#     307     self.eval()
#     308 else:
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/copy.py:271, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     269 if state is not None:
#     270     if deep:
# --> 271         state = deepcopy(state, memo)
#     272     if hasattr(y, '__setstate__'):
#     273         y.__setstate__(state)
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/copy.py:271, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     269 if state is not None:
#     270     if deep:
# --> 271         state = deepcopy(state, memo)
#     272     if hasattr(y, '__setstate__'):
#     273         y.__setstate__(state)
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
#     [... skipping similar frames: deepcopy at line 146 (14 times), _deepcopy_dict at line 231 (13 times), _reconstruct at line 271 (13 times), deepcopy at line 172 (13 times)]
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/copy.py:206, in _deepcopy_list(x, memo, deepcopy)
#     204 append = y.append
#     205 for a in x:
# --> 206     append(deepcopy(a, memo))
#     207 return y
#
#     [... skipping similar frames: deepcopy at line 146 (3 times), _deepcopy_dict at line 231 (2 times), _reconstruct at line 271 (2 times), deepcopy at line 172 (2 times)]
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/copy.py:206, in _deepcopy_list(x, memo, deepcopy)
#     204 append = y.append
#     205 for a in x:
# --> 206     append(deepcopy(a, memo))
#     207 return y
#
#     [... skipping similar frames: deepcopy at line 146 (9 times), _deepcopy_dict at line 231 (7 times), _reconstruct at line 271 (7 times), deepcopy at line 172 (7 times), _deepcopy_list at line 206 (1 times)]
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/copy.py:206, in _deepcopy_list(x, memo, deepcopy)
#     204 append = y.append
#     205 for a in x:
# --> 206     append(deepcopy(a, memo))
#     207 return y
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/copy.py:271, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     269 if state is not None:
#     270     if deep:
# --> 271         state = deepcopy(state, memo)
#     272     if hasattr(y, '__setstate__'):
#     273         y.__setstate__(state)
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/copy.py:138, in deepcopy(x, memo, _nil)
#     135     memo = {}
#     137 d = id(x)
# --> 138 y = memo.get(d, _nil)
#     139 if y is not _nil:
#     140     return y
#
# KeyboardInterrupt:
